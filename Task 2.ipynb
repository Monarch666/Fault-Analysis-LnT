# %% [markdown]
# # Task 2 of LnT internship

# %% [markdown]
# ### Task 2- Exploratory Data Analysis (EDA):
#
# Task: Explore the dataset to understand its characteristics and identify patterns or trends.
#
# Subtasks:
#
# Compute descriptive statistics to summarize key variables.
#
# Visualize data distributions using histograms, box plots, and other charts.
#
# Conduct bivariate and multivariate analysis to explore relationships between variables.

# %%
import pandas as pd
# Out:
# D:\Anaconda\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
import pandas as pd
file_path = 'C:\\Farmhouse\\LnTdata.csv'
df = pd.read_csv(file_path)

# %%
df
# Out:
#       G  C  B  A          Ia          Ib          Ic        Va        Vb  \
# 0     0  1  1  0    4.745460 -728.197739  725.778428 -0.318639 -0.011551
# 1     1  1  1  1 -525.497721  324.896235  201.390792 -0.046330  0.025836
# 2     0  1  1  1  311.575476 -882.660908  573.243395 -0.027955 -0.013439
# 3     0  1  1  1  875.922025 -542.215104 -331.644062  0.014291 -0.041649
# 4     1  0  0  1  752.530117   20.403523   27.205867  0.144196 -0.472389
# ...  .. .. .. ..         ...         ...         ...       ...       ...
# 3926  1  0  0  1  823.892102   32.743813   18.878951  0.075206 -0.392920
# 3927  1  0  1  1  717.943019 -815.951000  -21.165109 -0.004944 -0.107046
# 3928  0  0  0  0  -70.978494   68.994688   -1.006438 -0.206625 -0.381549
# 3929  0  0  0  0   55.050874   -4.783583  -53.315271  0.172090  0.426140
# 3930  0  0  0  0   15.426020  -28.088371    9.348891  0.582488 -0.185405
#
#             Vc
# 0     0.330189
# 1     0.020494
# 2     0.041393
# 3     0.027358
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print("\nDescriptive Statistics:")
df.describe()
# Out:
# Descriptive Statistics:
#                  G            C            B            A           Ia  \
# count  3931.000000  3931.000000  3931.000000  3931.000000  3931.000000
# mean      0.431951     0.411346     0.555584     0.571356    15.978095
# std       0.495411     0.492140     0.496964     0.494945   462.164811
# min       0.000000     0.000000     0.000000     0.000000  -883.468698
# 25%       0.000000     0.000000     0.000000     0.000000  -103.387364
# 50%       0.000000     0.000000     1.000000     1.000000     3.001744
# 75%       1.000000     1.000000     1.000000     1.000000   233.762445
# max       1.000000     1.000000     1.000000     1.000000   885.738571
#
#                 Ib           Ic           Va           Vb           Vc
# count  3931.000000  3931.000000  3931.000000  3931.000000  3931.000000
# mean    -54.217829    40.626001    -0.011358     0.004075     0.007283
# std     442.200192   369.811758     0.287772     0.314518     0.306257
# ...

# %% [markdown]
# By Loadng the dataset and describing it we can see that the faults in G,C,B,A are in binary form so we can use that to determine the type of faults in the Electrical Grid

# %% [markdown]
# Thus first we have to convert this binary indicators

# %%
df['Fault_Type'] = df[['G', 'C', 'B', 'A']].astype(str).agg(''.join, axis=1)

df
# Out:
#       G  C  B  A          Ia          Ib          Ic        Va        Vb  \
# 0     0  1  1  0    4.745460 -728.197739  725.778428 -0.318639 -0.011551
# 1     1  1  1  1 -525.497721  324.896235  201.390792 -0.046330  0.025836
# 2     0  1  1  1  311.575476 -882.660908  573.243395 -0.027955 -0.013439
# 3     0  1  1  1  875.922025 -542.215104 -331.644062  0.014291 -0.041649
# 4     1  0  0  1  752.530117   20.403523   27.205867  0.144196 -0.472389
# ...  .. .. .. ..         ...         ...         ...       ...       ...
# 3926  1  0  0  1  823.892102   32.743813   18.878951  0.075206 -0.392920
# 3927  1  0  1  1  717.943019 -815.951000  -21.165109 -0.004944 -0.107046
# 3928  0  0  0  0  -70.978494   68.994688   -1.006438 -0.206625 -0.381549
# 3929  0  0  0  0   55.050874   -4.783583  -53.315271  0.172090  0.426140
# 3930  0  0  0  0   15.426020  -28.088371    9.348891  0.582488 -0.185405
#
#             Vc Fault_Type
# 0     0.330189       0110
# 1     0.020494       1111
# ...

# %% [markdown]
# After defining it we can see how many types of faults are there in electrical grid through "Valuse count"

# %%
fault_types = {
    '0000': 'No Fault',
    '1000': 'Single Line to Ground A',
    '0100': 'Single Line to Ground B',
    '0010': 'Single Line to Ground C',
    '0011': 'Line-to-Line BC',
    '0101': 'Line-to-Line AC',
    '1001': 'Line-to-Line AB',
    '1010': 'Line-to-Line with Ground AB',
    '0101': 'Line-to-Line with Ground AC',
    '0110': 'Line-to-Line with Ground BC',
    '0111': 'Three-Phase',
    '1111': 'Three-Phase with Ground',
    '1011': 'Line A Line B to Ground Fault'
}

# %%
df['Fault_Type'] = df['Fault_Type'].map(fault_types)

df
# Out:
#       G  C  B  A          Ia          Ib          Ic        Va        Vb  \
# 0     0  1  1  0    4.745460 -728.197739  725.778428 -0.318639 -0.011551
# 1     1  1  1  1 -525.497721  324.896235  201.390792 -0.046330  0.025836
# 2     0  1  1  1  311.575476 -882.660908  573.243395 -0.027955 -0.013439
# 3     0  1  1  1  875.922025 -542.215104 -331.644062  0.014291 -0.041649
# 4     1  0  0  1  752.530117   20.403523   27.205867  0.144196 -0.472389
# ...  .. .. .. ..         ...         ...         ...       ...       ...
# 3926  1  0  0  1  823.892102   32.743813   18.878951  0.075206 -0.392920
# 3927  1  0  1  1  717.943019 -815.951000  -21.165109 -0.004944 -0.107046
# 3928  0  0  0  0  -70.978494   68.994688   -1.006438 -0.206625 -0.381549
# 3929  0  0  0  0   55.050874   -4.783583  -53.315271  0.172090  0.426140
# 3930  0  0  0  0   15.426020  -28.088371    9.348891  0.582488 -0.185405
#
#             Vc                     Fault_Type
# ...

# %%
fault_type_counts = df['Fault_Type'].value_counts()
fault_type_counts
# Out:
# Fault_Type
# No Fault                         1183
# Three-Phase with Ground           567
# Line A Line B to Ground Fault     567
# Line-to-Line AB                   564
# Three-Phase                       548
# Line-to-Line with Ground BC       502
# Name: count, dtype: int64

# %% [markdown]
# For visualisation and data distribution we will use Seaborn and matplotlib and use subplot to visualise

# %%
features = ['Ia', 'Ib', 'Ic', 'Va', 'Vb', 'Vc']
plt.figure(figsize=(12, 8))
for i, feature in enumerate(features):
    plt.subplot(2, 3, i+1)
    sns.histplot(df[feature], kde=True)
    plt.title(f'Distribution of {feature}')
plt.tight_layout()
plt.show()
# Out:
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %% [markdown]
# ### Then we found the Correlation

# %%
print("\nCorrelation Matrix:")
correlation_matrix = df[features].corr()
print(correlation_matrix)

# Here we used Heatmap of the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()
# Out:
# Correlation Matrix:
#           Ia        Ib        Ic        Va        Vb        Vc
# Ia  1.000000 -0.381653 -0.271209  0.034634 -0.269944  0.244682
# Ib -0.381653  1.000000 -0.529265  0.016814  0.035253 -0.052003
# Ic -0.271209 -0.529265  1.000000 -0.054452 -0.058115  0.110848
# Va  0.034634  0.016814 -0.054452  1.000000 -0.485810 -0.440727
# Vb -0.269944  0.035253 -0.058115 -0.485810  1.000000 -0.570487
# Vc  0.244682 -0.052003  0.110848 -0.440727 -0.570487  1.000000

# %% [markdown]
# ### Plotting the distribution of fault types

# %%
plt.figure(figsize=(10, 10))
sns.countplot(y=df["Fault_Type"])
plt.title("Distribution of Fault Types")
plt.xlabel("Count")
plt.ylabel("Fault Type")
plt.show()

# %% [markdown]
# ### Pairplot to observe pairwise relationships and distributions

# %%
sns.pairplot(df[features])
plt.suptitle("Pairwise Relationships of Features", y=1.02)
plt.show()
# Out:
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
plt.scatter(x="Ia",y="Va",data=df)

# %% [markdown]
# The graph wouldve been linear if there was no faults in the electrical system as we know that according to Ohms law we know that As current increases, the voltage also increases, but this is not the case in this scenario hence,This means that there are faults in Va and Ia.
